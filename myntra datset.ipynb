# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12860\3394212446.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Myntra Fasion Clothing.csv')

# %%
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
df.columns
# Out:
# Index(['URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %%
df['URL'].value_counts()
# Out:
# https://www.myntra.com/jeans/roadster/roadster-men-navy-blue-slim-fit-mid-rise-clean-look-jeans/2296012/buy                       1
# https://www.myntra.com/sarees/kalini/kalini-navy-blue--gold-toned-paisley-zari-silk-blend-saree/17821316/buy                      1
# https://www.myntra.com/sarees/pothys/pothys-women-yellow-geometric-printed-saree/17434400/buy                                     1
# https://www.myntra.com/sarees/shaily/shaily-blue--orange-pure-linen-printed-saree/10552660/buy                                    1
# https://www.myntra.com/sarees/shaily/shaily-blue-printed-pure-linen-saree/10552704/buy                                            1
#                                                                                                                                  ..
# https://www.myntra.com/trousers/colorplus/colorplus-men-brown-chinos-trousers/14444934/buy                                        1
# ...

# %%
df['BrandName'].value_counts()
# Out:
# Pothys                   16005
# Roadster                 10935
# KALINI                    9589
# HERE&NOW                  6515
# HRX by Hrithik Roshan     5297
#                          ...
# PIVOTO                       1
# PEONY SMART WORLD            1
# OFFIRA TEX WORLD             1
# Sztori Garfield              1
# Geonaute By Decathlon        1
# Name: BrandName, Length: 2088, dtype: int64

# %%
Brand_name=df.BrandName.value_counts().index

# %%
Brand_value=df.BrandName.value_counts().values

# %%
plt.pie(Brand_value[:10],labels=Brand_name[:10],autopct='%1.2f%%',radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa38ca1180>,
# ...
#  [Text(0.8445608339342509, 0.7047815248602101, 'Pothys'),
#   Text(-0.3200033536899947, 1.0524247496268588, 'Roadster'),
#   Text(-1.019956504110043, 0.41193291896086703, 'KALINI'),
#   Text(-1.0455742894194995, -0.34172270235515373, 'HERE&NOW'),
#   Text(-0.7430773581439223, -0.8110709215684219, 'HRX by Hrithik Roshan'),
#   Text(-0.3122669086182597, -1.0547461200601762, 'Mast & Harbour'),
#   Text(0.15782343938716498, -1.0886191997112702, 'Ethnic basket'),
#   Text(0.5806652519256134, -0.9342525703503116, 'Mitera'),
#   Text(0.9032526204836129, -0.627801484220519, 'Puma'),
#   Text(1.0776242203630588, -0.2207397555650315, 'max')],
#  [Text(0.4606695457823186, 0.38442628628738723, '22.14%'),
#   Text(-0.17454728383090617, 0.574049863432832, '15.12%'),
#   Text(-0.5563399113327506, 0.2246906830695638, '13.26%'),
#   Text(-0.5703132487742724, -0.18639420128462927, '9.01%'),
#   Text(-0.4053149226239576, -0.4424023208555028, '7.33%'),
# ...

# %% [markdown]
# observation: we can see the top most brand in myntra and pothys is no 1

# %%
#now find the all the things where brandname ==nike
df[df['BrandName']=='Nike'].groupby(['Category','DiscountPrice (in Rs)']).size().reset_index().rename(columns={0:'Rating count'})
# Out:
#         Category  DiscountPrice (in Rs)  Rating count
# 0    Bottom Wear                  877.0             1
# 1    Bottom Wear                  895.0             1
# 2    Bottom Wear                  897.0             2
# 3    Bottom Wear                  957.0             2
# 4    Bottom Wear                  971.0             1
# ..           ...                    ...           ...
# 239      Topwear                 1515.0             3
# 240      Topwear                 1525.0             1
# 241      Topwear                 1705.0             2
# 242      Topwear                 2085.0             3
# 243      Topwear                 2441.0             1
#
# [244 rows x 3 columns]

# %%
#find out which category has which price in nike brandname
df[df['BrandName']=='Nike'].groupby('DiscountPrice (in Rs)').size().reset_index().rename(columns={0:'Rating count'})
# Out:
#      DiscountPrice (in Rs)  Rating count
# 0                    638.0             2
# 1                    686.0             1
# 2                    717.0             1
# 3                    751.0             1
# 4                    762.0             1
# ..                     ...           ...
# 179                 4245.0             2
# 180                 4396.0             1
# 181                 4745.0             1
# 182                 4945.0             1
# 183                 5395.0             1
#
# [184 rows x 2 columns]

# %%
#top 10 invidual categories
df.columns
# Out:
# Index(['URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %%
inv_cate=df['Individual_category'].value_counts().index
inv_val=df['Individual_category'].value_counts().values

# %%
plt.pie(inv_val[:10],labels=inv_cate[:10],autopct='%1.2f%%',radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa3a2787c0>,
# ...
#  [Text(0.9469140126088383, 0.55978018250473, 'tshirts'),
#   Text(-0.00247591536815336, 1.0999972135615117, 'sarees'),
#   Text(-0.825568698673368, 0.7269362583959902, 'tops'),
#   Text(-1.099097335807255, 0.04455385978110584, 'kurtas'),
#   Text(-0.9015657081111644, -0.6302216070224941, 'dresses'),
#   Text(-0.3926690001957393, -1.0275266693790865, 'shirts'),
#   Text(0.16674620714697766, -1.0872882333595344, 'kurta-sets'),
#   Text(0.6247910470589272, -0.9053375875964774, 'jeans'),
#   Text(0.9483661298558438, -0.5573165023056909, 'trousers'),
#   Text(1.0863191693849354, -0.17294699253477674, 'bra')],
#  [Text(0.5164985523320935, 0.30533464500257995, '16.99%'),
#   Text(-0.0013504992917200145, 0.5999984801244608, '16.08%'),
#   Text(-0.4503101992763825, 0.3965106863978128, '10.87%'),
#   Text(-0.5995076377130482, 0.02430210533514864, '10.83%'),
#   Text(-0.49176311351518054, -0.34375724019408765, '9.88%'),
# ...

# %%
df['Individual_category'].unique()
# Out:
# array(['jeans', 'track-pants', 'shirts', 'shapewear', 'tshirts', 'tops',
#        'trousers', 'tights', 'kurta-sets', 'jumpsuit', 'kurtas', 'bra',
#        'shorts', 'dresses', 'bath-robe', 'jackets', 'socks', 'briefs',
#        'sweatshirts', 'sarees', 'trunk', 'kurtis', 'skirts',
#        'night-suits', 'lounge-pants', 'palazzos', 'stockings', 'jeggings',
#        'leggings', 'shrug', 'boxers', 'dupatta', 'tunics',
#        'innerwear-vests', 'sweaters', 'lounge-shorts', 'thermal-tops',
#        'capris', 'nightdress', 'pyjamas', 'sports-sandals', 'dungarees',
#        'tracksuits', 'camisoles', 'nehru-jackets', 'blazers',
#        'thermal-bottoms', 'lounge-tshirts', 'lehenga-choli', 'baby-dolls',
#        'coats', 'thermal-set', 'saree-blouse', 'churidar',
#        'dress-material', 'boots', 'lingerie-set', 'sherwani', 'co-ords',
#        'flats', 'swimwear', 'rain-jacket', 'patiala', 'salwar',
#        'harem-pants', 'patiala-and-dupatta', 'lingerie-accessories',
# ...

# %%
#top 10 brands of shirts
X=df[df['Individual_category'] == 'shirts']
t = X['BrandName'].value_counts().values
r = X['BrandName'].value_counts().index

# plt.figure(figsize = (30,20))
plt.pie(t[:10],labels=r[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa440e2fb0>,
# ...
#  [Text(0.9491526664084563, 0.5559759130121716, 'Roadster'),
#   Text(0.13955571135287217, 1.0911114532570878, 'Louis Philippe'),
#   Text(-0.6509710931172952, 0.8866998567303787, 'HIGHLANDER'),
#   Text(-1.0679153240681252, 0.2637363467944289, 'Allen Solly'),
#   Text(-1.0211063481632427, -0.40907435233796613, 'Louis Philippe Sport'),
#   Text(-0.6257277762738681, -0.9046904166616115, 'JAINISH'),
#   Text(-0.06567042571112858, -1.0980379752936231, 'Greenfibre'),
#   Text(0.4775811477044614, -0.9909168720721682, 'WROGN'),
#   Text(0.8750641688955948, -0.6665303446318571, 'Mast & Harbour'),
#   Text(1.0753840387163347, -0.23140693436918655, 'Mufti')],
#  [Text(0.5177196362227943, 0.30325958891572996, '16.87%'),
#   Text(0.07612129710156663, 0.5951517017765933, '12.22%'),
#   Text(-0.3550751417003428, 0.4836544673074792, '11.99%'),
#   Text(-0.5824992676735228, 0.14385618916059756, '10.15%'),
# ...

# %%
#top 5 nike categories
X=df[df['BrandName']=='Nike']
T=X['Individual_category'].value_counts().index
R=X['Individual_category'].value_counts().values
plt.pie(R[:5],labels=T[:5],autopct='%1.2f%%',radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa497a7550>,
# ...
#  [Text(-0.04213296689753347, 1.0991928006953156, 'tshirts'),
#   Text(-0.857043215861126, -0.689548349389961, 'shorts'),
#   Text(0.11733394775545383, -1.0937242544188734, 'track-pants'),
#   Text(0.7707276365697664, -0.7848432392698445, 'tights'),
#   Text(1.062422652976115, -0.2850580755621455, 'tops')],
#  [Text(-0.022981618307745526, 0.599559709470172, '51.22%'),
#   Text(-0.4674781177424323, -0.3761172814854332, '19.13%'),
#   Text(0.06400033513933845, -0.5965768660466582, '12.71%'),
#   Text(0.420396892674418, -0.428096312329006, '8.60%'),
#   Text(0.579503265259699, -0.15548622303389756, '8.34%')])

# %%
df.columns
# Out:
# Index(['URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %%
#topcategories purchased by men
Men=df[df['category_by_Gender']=='Men']
value=Men['Individual_category'].value_counts().values
label=Men['Individual_category'].value_counts().index

# %%
plt.pie(value[:10],labels=label[:10],autopct='%1.2f%%',radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa48b792d0>,
# ...
#  [Text(0.7547541146831845, 0.8002163622226195, 'tshirts'),
#   Text(-0.6496729160929671, 0.88765145304633, 'shirts'),
#   Text(-1.0999705328484217, 0.008051513221708112, 'jeans'),
#   Text(-0.850715882440312, -0.6973395782284276, 'trousers'),
#   Text(-0.3367498987802122, -1.0471864712989358, 'track-pants'),
#   Text(0.16585830930957493, -1.0874240300972613, 'kurta-sets'),
#   Text(0.6030844189782696, -0.9199397717164115, 'kurtas'),
#   Text(0.9044204686866724, -0.6261178929088196, 'shorts'),
#   Text(1.0490704788972334, -0.3308339920660055, 'sweatshirts'),
#   Text(1.0952137697918496, -0.10250267537155133, 'jackets')],
#  [Text(0.41168406255446427, 0.43648165212142875, '25.93%'),
#   Text(-0.3543670451416184, 0.48417351984345264, '18.25%'),
#   Text(-0.59998392700823, 0.004391734484568061, '11.41%'),
#   Text(-0.4640268449674429, -0.3803670426700514, '10.68%'),
#   Text(-0.18368176297102481, -0.5711926207085104, '7.56%'),
# ...

# %%
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
sns.countplot(x='category_by_Gender',hue='',data=df)
# Out:
# <Axes: xlabel='category_by_Gender', ylabel='count'>
