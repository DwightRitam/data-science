# %% [markdown]
# <a href="https://colab.research.google.com/github/DwightRitam/data-science/blob/main/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program","started","by","Campusx",sep='-')
# Out:
# Data-Science-Mentorship-Program-started-by-Campusx

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celcius=float(input("enter the celcius value -"))
fahrenheit=(celcius*9/5)+32
print(fahrenheit)
# Out:
# enter the celcius value -39
# 102.2

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a=int(input("enter the first number -"))
b=int(input("enter the second number -"))
c=a
a=b
b=c
print("the first number is",a)
print("the second number is",b)
# Out:
# enter the first number -12
# enter the second number -23
# the first number is 23
# the second number is 12

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
name1, name2 = input("Enter two names: ").split()

print(f"First: {name1}")
print(f"Second: {name2}")
# Out:
# Enter two names: kriste ritam
# First: kriste
# Second: ritam

# %%
c1,c2=map(int, input("Enter the first coordinate - ").split())
c3,c4=map(int,input("enter the second coordinate - ").split())
print((c1-c3)**2+(c2-c4)**2)
# Out:
# Enter the first coordinate - 1 2
# enter the second coordinate - 2 3
# 2

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p=int(input("enter the principle amount -"))
r=int(input("enter the rate of interest -"))
t=int(input("enter the time period -"))
print((p*r*t)/100)
# Out:
# enter the principle amount -12000
# enter the rate of interest -10
# enter the time period -12
# 14400.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n=int(input("enter the number - "))
sum=0
for i in range(1,n+1):
  sum=sum+ i**2
  print(sum)
print(int((n*(n+1)*(2*n+1))/6))
# Out:
# enter the number - 5
# 1
# 5
# 14
# 30
# 55
# 55

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a,b,n=map(int,input("enter the first 2 terms and n -").split())
diff=b-a
print(a+(n-1)*diff)
# Out:
# enter the first 2 terms and n -7 12 20
# 102

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
h,l,b =map(int,input("enter the height,width,breadth ").split())
print("the volume is : ", h*l*b)
# Out:
# enter the height,width,breadth 12 34 45
# the volume is :  18360
